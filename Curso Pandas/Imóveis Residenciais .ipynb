# %% [markdown]
# # Relatório de Análise III

# %% [markdown]
# ## Imóveis Residenciais

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados_pandas/aluguel.csv', sep=';')

# %%
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %%
residencial = list(dados['Tipo'].drop_duplicates())

# %%
dados['Tipo'].isin(residencial).head(10)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: Tipo, dtype: bool

# %%
selecao = dados['Tipo'].isin(residencial)

# %%
dados_residencial = dados[selecao]

# %%
list(dados_residencial['Tipo'].drop_duplicates())
# Out:
# ['Quitinete',
#  'Casa',
#  'Conjunto Comercial/Sala',
#  'Apartamento',
#  'Casa de Condomínio',
#  'Prédio Inteiro',
#  'Flat',
#  'Loja/Salão',
#  'Galpão/Depósito/Armazém',
#  'Casa Comercial',
#  'Casa de Vila',
#  'Terreno Padrão',
#  'Box/Garagem',
#  'Loft',
#  'Loja Shopping/ Ct Comercial',
#  'Chácara',
#  'Loteamento/Condomínio',
#  'Sítio',
#  'Pousada/Chalé',
#  'Studio',
#  'Hotel',
#  'Indústria']

# %%
dados_residencial.shape[0]
# Out:
# 32960

# %%
dados_residencial.index = range(dados_residencial.shape[0])

# %%
dados_residencial
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %% [markdown]
# ## Exportando a base de dados

# %%
dados_residencial.to_csv('dados_pandas/aluguel_residencial.csv', sep = ';')

# %%
dados_residencia_2 = pd.read_csv('dados_pandas/aluguel_residencial.csv', sep = ';')

# %%
dados_residencia_2
# Out:
#        Unnamed: 0                     Tipo                Bairro  Quartos  \
# 0               0                Quitinete            Copacabana        1
# 1               1                     Casa       Jardim Botânico        2
# 2               2  Conjunto Comercial/Sala       Barra da Tijuca        0
# 3               3              Apartamento                Centro        1
# 4               4              Apartamento          Higienópolis        1
# ...           ...                      ...                   ...      ...
# 32955       32955                Quitinete                Centro        0
# 32956       32956              Apartamento           Jacarepaguá        3
# 32957       32957              Apartamento  São Francisco Xavier        2
# 32958       32958              Apartamento                Leblon        2
# 32959       32959  Conjunto Comercial/Sala                Centro        0
#
#        Vagas  Suites  Area   Valor  Condominio    IPTU
# ...

# %%
dados_residencial.to_csv('dados_pandas/aluguel_residencial.csv', sep = ';',index = False)

# %%
dados_residencia_2 = pd.read_csv('dados_pandas/aluguel_residencial.csv', sep = ';')

# %%
dados_residencia_2
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...
